# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from core.database import *

# %%
from utils.notebook_setup import setup_project

# %%
print(database_exists())

# %%
create_tables()

# %%
print(database_exists())

# %%
conn = connect()

print(type(conn))

close(conn)

# %%
#reset_database()

# %%
conn = connect()

cursor = conn.cursor()

cursor.execute("""
SELECT name
FROM sqlite_master
WHERE type='table'
""")

for row in cursor.fetchall():
    print(row["name"])

close(conn)

# %%
conn = connect()

cursor = conn.cursor()

cursor.execute("PRAGMA table_info(objects)")

for row in cursor.fetchall():
    print(dict(row))

close(conn)

# %%
conn = connect()

cursor = conn.cursor()

tables = [
    "topics",
    "researchers",
    "papers",
    "topic_links",
    "topic_researchers",
    "topic_papers"
]

for table in tables:

    print("\n" + "=" * 60)
    print(table.upper())
    print("=" * 60)

    cursor.execute(f"PRAGMA table_info({table})")

    for row in cursor.fetchall():
        print(dict(row))

close(conn)

# %%
sync_topics()

# %%
conn = connect()

cursor = conn.cursor()

cursor.execute("SELECT * FROM topics")

for row in cursor.fetchall():

    print(dict(row))

close(conn)

# %%
import importlib

import core.database as db

importlib.reload(db)

# %%
db.get_all_topic_names()

# %%
db.get_all_entity_names("topic")

# %%
db.entity_exists(
    "topic",
    "Mathematics"
)

# %%
db.entity_exists(
    "topic",
    "Physics"
)

# %%
db.get_topic_overview(
    "Mathematics"
)

# %%
db.get_topic_history(
    "Mathematics"
)

# %%
db.get_topic_timeline(
    "Mathematics"
)

# %%
db.get_topic_researchers(
    "Mathematics"
)

# %%
db.get_topic_relationships(
    "Mathematics"
)

# %%
db.build_learning_context(
    "Mathematics"
)

# %%
db.build_history_context(
    "Mathematics"
)

# %%
db.build_complete_context(
    "Mathematics"
)

# %%
db.build_curiosity_context(
    "Mathematics"
)

# %%
db.build_learning_path(
    "Mathematics"
)

# %%
import importlib

import core.database as db

importlib.reload(db)

# %%
db.get_all_topic_names()

# %%
db.get_all_entity_names(
    "topic"
)
