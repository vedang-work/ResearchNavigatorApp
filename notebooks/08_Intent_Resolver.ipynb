# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
import importlib

import core.database as db

importlib.reload(db)
# Out:
# <module 'core.database' from 'C:\\Users\\AMISHA SINGH\\Desktop\\Work\\June, 2026\\research_navigator\\core\\database.py'>

# %%
import agents.intent_resolver as ir

importlib.reload(ir)

resolver = ir.IntentResolver()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 import agents.intent_resolver as ir
#       2
#       3 importlib.reload(ir)
#       4
# ----> 5 resolver = ir.IntentResolver()
#
# File ~\Desktop\Work\June, 2026\research_navigator\agents\intent_resolver.py:213, in IntentResolver.__init__(self)
#     211 def __init__(self):
# --> 213     self.topic_names = get_all_entity_names("topic")
#     215     self.researcher_names = get_all_entity_names(
#     216
#     217         "researcher"
#     218
#     219     )
#     221     self.paper_titles = get_all_entity_names(
#     222
#     223         "paper"
#     224
#     225     )
#
# File ~\Desktop\Work\June, 2026\research_navigator\core\database.py:166, in get_all_entity_names(entity_type)
#     162 if loader is None:
#     164     return []
# --> 166 return loader()
#
# File ~\Desktop\Work\June, 2026\research_navigator\core\database.py:29, in get_all_topic_names()
#      15 def get_all_topic_names() -> List[str]:
#      16     """
#      17     Return all topic names.
#      18
#    (...)     26     AI
#      27     """
# ---> 29     conn = connect()
#      31     cursor = conn.cursor()
#      33     cursor.execute("""
#      34
#      35         SELECT name
#    (...)     41
#      42     """)
#
# NameError: name 'connect' is not defined
