# %%
from utils.notebook_setup import setup_project

setup_project()
# Out:
# ...
# RESEARCH NAVIGATOR
# ...
# Project Root
# C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
# ...
# PROJECT VERIFICATION
# ...
# Root : C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
#
# core            OK
# agents          OK
# knowledge       OK
# notebooks       OK
# ...
#
# ...
# RELOADING MODULES
# ...
#
# Reloaded : core.schema
# Reloaded : core.builder
# Reloaded : core.knowledge
# Reloaded : core.database
# Reloaded : core.quality
# Reloaded : agents.ollama_client
# Reloaded : agents.research_assistant
#
# ...
# Reload Complete
# ...
# OLLAMA
# ...
# Status : Running
#
# Installed Models
# ----------------
# llama3.2:3b
# qwen3:4b
# ...
#
#
# Notebook Ready.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from core.knowledge import *
from core.database import *

# %%
mathematics = create_object({

    "type": "topic",

    "name": "Mathematics",

    "overview": "",

    "metadata": {},

    "content": {},

    "relationships": {}

})

# %%
mathematics["metadata"] = {

    "domain": "Artificial Intelligence",

    "subdomain": "Foundations",

    "difficulty": "Beginner",

    "estimated_study_time": "12-15 Hours",

    "importance": "Critical",

    "quality_level": "Gold",

    "version": "1.0",

    "author": "Research Navigator",

    "tags": [

        "Artificial Intelligence",

        "Mathematics",

        "Statistics",

        "Machine Learning",

        "Deep Learning"

    ]

}

# %%
mathematics["overview"] = (
    "Mathematics is the fundamental language of Artificial Intelligence. "
    "Every AI system—from simple regression models to modern Large Language Models—"
    "uses mathematical principles to represent data, learn patterns, optimize decisions, "
    "and reason under uncertainty. A strong mathematical foundation enables researchers "
    "to understand not only how AI models work, but also why they work."
)

mathematics["content"]["why_it_matters"] = [

    "Mathematics provides the language used to describe intelligent systems and algorithms.",

    "Optimization techniques enable AI models to learn from data by minimizing errors.",

    "Probability and statistics allow AI systems to reason under uncertainty.",

    "Linear algebra enables efficient representation of high-dimensional data used in machine learning.",

    "Calculus makes gradient-based learning and neural network training possible."

]

mathematics["content"]["intuition"] = (

    "Imagine trying to build a bridge without understanding physics. "
    "Similarly, building AI systems without mathematics allows you to use existing tools, "
    "but makes it difficult to understand why algorithms behave as they do. "
    "Mathematics provides the reasoning framework behind every intelligent model."

)

mathematics["content"]["key_concepts"] = [

    "Linear Algebra",

    "Probability",

    "Statistics",

    "Calculus",

    "Optimization",

    "Discrete Mathematics"

]

mathematics["content"]["prerequisites"] = [

    "Basic Algebra",

    "Functions",

    "Graphs",

    "High School Calculus"

]

mathematics["content"]["key_takeaways"] = [

    "Mathematics forms the foundation of every AI discipline.",

    "Learning mathematics enables deeper understanding rather than memorizing algorithms.",

    "Strong mathematical intuition accelerates research and innovation.",

    "Most modern AI breakthroughs are grounded in mathematical discoveries."

]

# %%
mathematics["relationships"] = {

    "parent_topics": [],

    "child_topics": [

        "Statistics",

        "Probability",

        "Linear Algebra",

        "Calculus",

        "Optimization"

    ],

    "related_topics": [

        "Machine Learning",

        "Deep Learning"

    ]

}

# %%
valid, missing = validate_object(mathematics)

print("Valid:", valid)

print("Missing:", missing)
# Out:
# Valid: True
# Missing: []

# %%
save_object(mathematics)
# Out:
# WindowsPath('C:/Users/AMISHA SINGH/Desktop/Work/June, 2026/research_navigator/knowledge/topics/Mathematics.json')

# %%
loaded = load_object("topic", "Mathematics")

print(loaded["name"])
print()
print(loaded["metadata"]["domain"])
print()
print(loaded["content"]["key_concepts"])
# Out:
# Mathematics
#
# Artificial Intelligence
#
# ['Linear Algebra', 'Probability', 'Statistics', 'Calculus', 'Optimization', 'Discrete Mathematics']

# %%
sync_topics()
# Out:
# Found 1 topic files
#
# ✓ Mathematics
#
# ---------------------
# Topics Loaded : 1

# %%
conn = connect()

cursor = conn.cursor()

cursor.execute("SELECT * FROM topics")

for row in cursor.fetchall():

    print(dict(row))

close(conn)
# Out:
# {'id': 2, 'name': 'Mathematics', 'overview': 'Mathematics is the fundamental language of Artificial Intelligence. Every AI system—from simple regression models to modern Large Language Models—uses mathematical principles to represent data, learn patterns, optimize decisions, and reason under uncertainty. A strong mathematical foundation enables researchers to understand not only how AI models work, but also why they work.', 'importance': '', 'json_path': 'C:\\Users\\AMISHA SINGH\\Desktop\\Work\\June, 2026\\research_navigator\\knowledge\\topics\\Mathematics.json'}

# %%
mathematics["content"]["historical_motivation"] = {

    "problem_before": (
        "Long before Artificial Intelligence existed, scientists struggled to "
        "describe patterns, uncertainty and change in a rigorous way. There was "
        "no universal language capable of explaining how systems behaved or how "
        "predictions could be made from observations."
    ),

    "why_it_emerged": (
        "Mathematics evolved over centuries as a universal language for reasoning, "
        "measurement and problem solving. It gradually became the foundation upon "
        "which statistics, optimization and eventually Artificial Intelligence "
        "were built."
    ),

    "impact_on_ai": (
        "Modern AI inherits almost every mathematical tool developed over the last "
        "four centuries. Without mathematics there would be no probability, no "
        "optimization, no neural networks and no machine learning."
    )

}

# %%
mathematics["content"]["timeline"] = [

    {
        "year": 1654,
        "event": "Birth of Probability Theory",
        "researchers": [
            "Blaise Pascal",
            "Pierre de Fermat"
        ],
        "importance": (
            "Laid the mathematical foundation for reasoning under uncertainty."
        )
    },

    {
        "year": 1687,
        "event": "Calculus Formalized",
        "researchers": [
            "Isaac Newton"
        ],
        "importance": (
            "Introduced mathematical tools used today in optimization and deep learning."
        )
    },

    {
        "year": 1805,
        "event": "Least Squares Method",
        "researchers": [
            "Carl Friedrich Gauss"
        ],
        "importance": (
            "Became one of the earliest optimization techniques used for fitting models."
        )
    },

    {
        "year": 1763,
        "event": "Bayes' Theorem Published",
        "researchers": [
            "Thomas Bayes"
        ],
        "importance": (
            "Established the mathematical basis of probabilistic reasoning."
        )
    }

]

# %%
mathematics["content"]["timeline"] = [

    {
        "year": 1654,
        "event": "Birth of Probability Theory",
        "researchers": [
            "Blaise Pascal",
            "Pierre de Fermat"
        ],
        "importance": (
            "Laid the mathematical foundation for reasoning under uncertainty."
        )
    },

    {
        "year": 1687,
        "event": "Calculus Formalized",
        "researchers": [
            "Isaac Newton"
        ],
        "importance": (
            "Introduced mathematical tools used today in optimization and deep learning."
        )
    },

    {
        "year": 1805,
        "event": "Least Squares Method",
        "researchers": [
            "Carl Friedrich Gauss"
        ],
        "importance": (
            "Became one of the earliest optimization techniques used for fitting models."
        )
    },

    {
        "year": 1763,
        "event": "Bayes' Theorem Published",
        "researchers": [
            "Thomas Bayes"
        ],
        "importance": (
            "Established the mathematical basis of probabilistic reasoning."
        )
    }

]

# %%
mathematics["content"]["applications"] = [

    {
        "field": "Machine Learning",
        "usage": "Training predictive models."
    },

    {
        "field": "Computer Vision",
        "usage": "Image representation and optimization."
    },

    {
        "field": "Natural Language Processing",
        "usage": "Vector embeddings and probability models."
    },

    {
        "field": "Robotics",
        "usage": "Control systems and motion planning."
    },

    {
        "field": "Healthcare AI",
        "usage": "Medical image analysis and diagnosis."
    }

]

# %%
mathematics["content"]["open_problems"] = [

    "Can deep learning be completely explained mathematically?",

    "Can scaling laws be derived from first principles?",

    "Can mathematical guarantees improve AI safety?",

    "How can uncertainty be represented more effectively in foundation models?"

]

# %%
mathematics["content"]["future_directions"] = [

    "Theory of Foundation Models",

    "Mathematical AI Safety",

    "Interpretable Optimization",

    "Probabilistic Deep Learning",

    "Neural Scaling Laws"

]

# %%
mathematics["content"]["faqs"] = [

    {
        "question": "Why is mathematics considered the foundation of AI?",
        "answer": (
            "Every AI algorithm ultimately relies on mathematical concepts such as "
            "linear algebra, calculus, probability and optimization."
        )
    },

    {
        "question": "Which mathematical subjects should every AI researcher master?",
        "answer": (
            "Linear algebra, probability, statistics, calculus and optimization form "
            "the core mathematical toolkit for AI research."
        )
    },

    {
        "question": "Can someone become an AI researcher without advanced mathematics?",
        "answer": (
            "Basic AI applications can be developed with limited mathematics, but "
            "research and innovation require a much deeper mathematical understanding."
        )
    }

]

# %%
save_object(mathematics)

sync_topics()

print("✓ Gold Standard Mathematics node updated.")
# Out:
# Found 1 topic files
#
# ✓ Mathematics
#
# ---------------------
# Topics Loaded : 1
# ✓ Gold Standard Mathematics node updated.
