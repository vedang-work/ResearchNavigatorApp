# %%
from utils.notebook_setup import setup_project

setup_project()
# Out:
# ...
# RESEARCH NAVIGATOR
# ...
# Project Root
# C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
# ...
# PROJECT VERIFICATION
# ...
# Root : C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
#
# core            OK
# agents          OK
# knowledge       OK
# notebooks       OK
# ...
#
# ...
# RELOADING MODULES
# ...
#
# Reloaded : core.schema
# Reloaded : core.builder
# Reloaded : core.knowledge
# Reloaded : core.database
# Reloaded : core.quality
# Reloaded : agents.ollama_client
# Reloaded : agents.research_assistant
#
# ...
# Reload Complete
# ...
# OLLAMA
# ...
# Status : Running
#
# Installed Models
# ----------------
# llama3.2:3b
# qwen3:4b
# ...
#
#
# Notebook Ready.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
import os
from core.database import DATABASE_PATH

print(DATABASE_PATH)
print(os.path.exists(DATABASE_PATH))
# Out:
# C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator\data\research_universe.db
# True

# %%
import os

if os.path.exists(DATABASE_PATH):
    os.remove(DATABASE_PATH)
    print("Database deleted successfully.")
else:
    print("Database already absent.")
# Out:
# Database deleted successfully.

# %%
print(os.path.exists(DATABASE_PATH))
# Out:
# False

# %%
from core.database import *

initialize_database()

print("Database initialized.")
# Out:
# Database initialized.

# %%
conn = connect()

cursor = conn.cursor()

cursor.execute("PRAGMA table_info(topics)")

for row in cursor.fetchall():
    print(dict(row))

close(conn)
# Out:
# {'cid': 0, 'name': 'id', 'type': 'INTEGER', 'notnull': 0, 'dflt_value': None, 'pk': 1}
# {'cid': 1, 'name': 'name', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}
# {'cid': 2, 'name': 'overview', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}
# {'cid': 3, 'name': 'quality', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}
# {'cid': 4, 'name': 'json_path', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}

# %%
import inspect
import core.database as db

print(db.__file__)
print()
print(inspect.getsource(db.create_tables))
# Out:
# C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator\core\database.py
#
# def create_tables():
#
#     conn = connect()
#
#     cursor = conn.cursor()
#
#     # ------------------------------------------------------
#     # TOPICS
#     # ------------------------------------------------------
#
#     cursor.execute("""
#
#     CREATE TABLE IF NOT EXISTS topics(
#
#         id INTEGER PRIMARY KEY AUTOINCREMENT,
#
#         name TEXT UNIQUE,
#
#         overview TEXT,
#
#         quality TEXT,
#
#         json_path TEXT
#
#     )
#
#     """)
#
#     # ------------------------------------------------------
#     # RESEARCHERS
#     # ------------------------------------------------------
#
#     cursor.execute("""
#
#     CREATE TABLE IF NOT EXISTS researchers(
#
#         id INTEGER PRIMARY KEY AUTOINCREMENT,
#
#         name TEXT UNIQUE,
#
#         summary TEXT,
#
#         json_path TEXT
#
#     )
#
#     """)
#
# ...

# %%
conn = connect()

cursor = conn.cursor()

cursor.execute("PRAGMA table_info(topics)")

for row in cursor.fetchall():
    print(dict(row))

close(conn)
# Out:
# {'cid': 0, 'name': 'id', 'type': 'INTEGER', 'notnull': 0, 'dflt_value': None, 'pk': 1}
# {'cid': 1, 'name': 'name', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}
# {'cid': 2, 'name': 'overview', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}
# {'cid': 3, 'name': 'quality', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}
# {'cid': 4, 'name': 'json_path', 'type': 'TEXT', 'notnull': 0, 'dflt_value': None, 'pk': 0}

# %%
sync_all()

# %%
print(database_statistics())
# Out:
# {'topics': 1, 'researchers': 0, 'papers': 0, 'topic_links': 0, 'topic_researchers': 0, 'topic_papers': 0}
