# %%
from utils.notebook_setup import setup_project

setup_project()
# Out:
# ============================================================
# RESEARCH NAVIGATOR
# ============================================================
# Project Root
# C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
# ============================================================
# ============================================================
# PROJECT VERIFICATION
# ============================================================
# Root : C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
#
# core            OK
# agents          OK
# knowledge       OK
# notebooks       OK
# ============================================================
#
# ============================================================
# RELOADING MODULES
# ============================================================
#
# Reloaded : core.schema
# Reloaded : core.builder
# Reloaded : core.knowledge
# Reloaded : core.database
# Reloaded : core.quality
# Reloaded : agents.ollama_client
# Reloaded : agents.research_assistant
#
# ============================================================
# Reload Complete
# ============================================================
# ============================================================
# OLLAMA
# ============================================================
# Status : Running
#
# Installed Models
# ----------------
# llama3.2:3b
# qwen3:4b
# ============================================================
#
#
# Notebook Ready.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from agents.ollama_client import OllamaClient

client = OllamaClient()

# %%
client.is_running()
# Out:
# True

# %%
client.list_models()
# Out:
# ['llama3.2:3b', 'qwen3:4b']

# %%
client.server_status()
# Out:
# {'running': True,
#  'host': 'http://localhost:11434',
#  'model_count': 2,
#  'models': ['llama3.2:3b', 'qwen3:4b']}

# %%
client.print_models()
# Out:
# ============================================================
# INSTALLED OLLAMA MODELS
# ============================================================
# llama3.2:3b                 1.88 GB
# qwen3:4b                    2.33 GB
# ============================================================

# %%
response = client.generate(
    model="qwen3:4b",
    prompt="Explain what Artificial Intelligence is in one paragraph."
)

print(response)
# Out:
# Artificial Intelligence (AI) refers to the capability of machines to simulate human intelligence by learning from data, identifying patterns, and making decisions or predictions without being explicitly programmed for every specific task. It involves developing systems that can perform tasks typically requiring human cognition—such as problem-solving, pattern recognition, natural language understanding, and adaptive behavior—by using algorithms, large datasets, and computational power to improve their performance over time through experience. Unlike rigid rule-based systems, modern AI (particularly machine learning and deep learning) enables computers to autonomously discover insights and optimize outcomes in complex real-world scenarios, such as healthcare diagnostics, autonomous vehicles, and personalized recommendations, while operating within defined ethical and technical boundaries.

# %%
response = client.chat(
    model="llama3.2:3b",
    question="What is Machine Learning?"
)

print(response)
# Out:
# Machine learning (ML) is a subset of artificial intelligence (AI) that involves training algorithms to make predictions or decisions based on data. The goal of machine learning is to enable computers to learn from experience, without being explicitly programmed for each task.
#
# In traditional programming, a computer is given a set of rules and instructions to follow in order to complete a specific task. In contrast, machine learning allows the computer to discover these rules and patterns through the process of training on large datasets.
#
# Machine learning algorithms can be broadly categorized into three types:
#
# 1. **Supervised Learning**: The algorithm is trained on labeled data, where each example is associated with a target output. The goal is to learn a mapping between input data and output labels.
# 2. **Unsupervised Learning**: The algorithm is trained on unlabeled data, and it must find patterns or structure in the data on its own.
# 3. **Reinforcement Learning**: The algorithm learns through trial and error by interacting with an environment and receiving feedback in the form of rewards or penalties.
#
# Some common applications of machine learning include:
#
# 1. **Image Recognition**: Machine learning algorithms can be trained to recognize objects, faces, and patterns in images.
# 2. **Natural Language Processing (NLP)**: Machine learning can be used for text analysis, sentiment analysis, and language translation.
# 3. **Predictive Modeling**: Machine learning algorithms can be used to predict outcomes based on historical data, such as stock prices or customer churn.
# 4. **Recommendation Systems**: Machine learning can be used to recommend products or services based on user behavior and preferences.
#
# Machine learning has many benefits, including:
#
# 1. **Improved Accuracy**: Machine learning algorithms can learn from large datasets and improve their accuracy over time.
# 2. **Increased Efficiency**: Machine learning can automate tasks and reduce the need for manual intervention.
# 3. **Scalability**: Machine learning can handle large amounts of data and scale to meet the needs of growing organizations.
#
# However, machine learning also has some challenges and limitations, including:
#
# 1. **Data Quality**: Machine learning algorithms require high-quality data to learn effectively.
# 2. **Bias and Fairness**: Machine learning algorithms can perpetuate biases in the data and lead to unfair outcomes.
# 3. **Explainability**: Machine learning models can be difficult to interpret and understand.
#
# Overall, machine learning is a powerful tool for automating tasks and making predictions based on data. However, it requires careful consideration of its limitations and challenges to ensure that it is used effectively and responsibly.

# %%
result = client.benchmark(
    model="qwen3:4b"
)

print(result["model"])
print(result["seconds"])
print(result["characters"])
# Out:
# qwen3:4b
# 288.7
# 1378
