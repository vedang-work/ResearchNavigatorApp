# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
import importlib

import core.schema as schema

importlib.reload(schema)
# Out:
# <module 'core.schema' from 'C:\\Users\\AMISHA SINGH\\Desktop\\Work\\June, 2026\\research_navigator\\core\\schema.py'>

# %%
from core.schema import *

intent = Intent(

    action=ActionType.EXPLAIN,

    entities=[

        Entity(

            entity_type=EntityType.TOPIC,

            name="Mathematics"

        )

    ],

    requested_sections=[

        "history"

    ],

    raw_question="Explain the history of Mathematics."

)

intent
# Out:
# Intent(action=<ActionType.EXPLAIN: 'explain'>, entities=[Entity(entity_type=<EntityType.TOPIC: 'topic'>, name='Mathematics', confidence=1.0)], requested_sections=['history'], detail_level=<DetailLevel.BASIC: 'basic'>, raw_question='Explain the history of Mathematics.', confidence=1.0)

# %%
response = KnowledgeResponse(

    answer="Mathematics is the foundation of AI."

)

response
# Out:
# KnowledgeResponse(answer='Mathematics is the foundation of AI.', timeline=[], researchers=[], papers=[], related_topics=[], suggested_questions=[], learning_path=[], confidence=1.0, metadata={})
