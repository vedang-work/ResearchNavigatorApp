# %%
from utils.notebook_setup import setup_project

setup_project()
# Out:
# ...
# RESEARCH NAVIGATOR
# ...
# Project Root
# C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
# ...
# PROJECT VERIFICATION
# ...
# Root : C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
#
# core            OK
# agents          OK
# knowledge       OK
# notebooks       OK
# ...
#
# ...
# RELOADING MODULES
# ...
#
# Reloaded : core.schema
# Reloaded : core.builder
# Reloaded : core.knowledge
# Reloaded : core.database
# Reloaded : core.quality
# Reloaded : agents.ollama_client
# Reloaded : agents.research_assistant
#
# ...
# Reload Complete
# ...
# OLLAMA
# ...
# Status : Running
#
# Installed Models
# ----------------
# llama3.2:3b
# qwen3:4b
# ...
#
#
# Notebook Ready.

# %%
import sys
import json
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from core.knowledge import *

# %%
print("Project Root :", PROJECT_ROOT)
print("Knowledge Engine Imported Successfully")
# Out:
# Project Root : C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator
# Knowledge Engine Imported Successfully

# %%
mathematics = create_object({

    "type": "topic",

    "name": "Mathematics",

    "overview": "Foundation of Artificial Intelligence.",

    "metadata": {
        "domain": "Artificial Intelligence"
    },

    "content": {
        "importance": "Every AI system depends on mathematics."
    },

    "relationships": {
        "children": [
            "Statistics"
        ]
    }

})

# %%
valid, missing = validate_object(mathematics)

print(valid)
print(missing)
# Out:
# True
# []

# %%
save_object(mathematics)
# Out:
# WindowsPath('C:/Users/AMISHA SINGH/Desktop/Work/June, 2026/research_navigator/knowledge/topics/Mathematics.json')

# %%
print(object_exists("topic", "Mathematics"))
# Out:
# True

# %%
loaded = load_object("topic", "Mathematics")

print(loaded["name"])
# Out:
# Mathematics

# %%
print(list_objects("topic"))
# Out:
# ['Mathematics']

# %%
print(search_objects("topic", "foundation"))
# Out:
# ['Mathematics']

# %%
update_object(

    "topic",

    "Mathematics",

    {

        "overview": "The mathematical foundation behind modern Artificial Intelligence."

    }

)
# Out:
# {'type': 'topic',
#  'name': 'Mathematics',
#  'overview': 'The mathematical foundation behind modern Artificial Intelligence.',
#  'metadata': {'domain': 'Artificial Intelligence'},
#  'content': {'importance': 'Every AI system depends on mathematics.'},
#  'relationships': {'children': ['Statistics']}}

# %%
topic = load_object("topic", "Mathematics")

print(topic["overview"])
# Out:
# The mathematical foundation behind modern Artificial Intelligence.

# %%
#delete_object("topic", "Mathematics")

#print(object_exists("topic", "Mathematics"))
