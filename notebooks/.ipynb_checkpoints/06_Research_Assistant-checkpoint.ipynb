# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project Root:", PROJECT_ROOT)
# Out:
# Project Root: C:\Users\AMISHA SINGH\Desktop\Work\June, 2026\research_navigator

# %%
from utils.notebook_setup import setup_project

# %%
from agents.research_assistant import *

assistant = ResearchAssistant()

# %%
assistant.health()
# Out:
# {'ollama': True, 'models': ['llama3.2:3b', 'qwen3:4b']}

# %%
assistant.available_models()
# Out:
# ['llama3.2:3b', 'qwen3:4b']

# %%
assistant.choose_model(
    "Explain Machine Learning."
)
# Out:
# 'llama3.2:3b'

# %%
assistant.choose_model(
    "Compare CNN and Vision Transformer."
)
# Out:
# 'qwen3:4b'

# %%
assistant.topic_exists(
    "Mathematics"
)
# Out:
# True

# %%
assistant.build_context(
    "Mathematics"
)
# Out:
# {'topic': {'type': 'topic',
#   'identity': {'name': 'Mathematics',
#    'domain': 'Artificial Intelligence',
#    'subdomain': 'Foundations',
#    'difficulty': 'Beginner',
#    'importance': 'Critical',
#    'estimated_study_time': '15 Hours',
#    'quality_level': 'Gold',
#    'version': '1.0',
#    'tags': ['AI', 'Mathematics']},
#   'learning': {'overview': 'Mathematics is the language of Artificial Intelligence.',
#    'why_it_matters': ['Optimization allows AI models to learn.',
#     'Probability enables reasoning under uncertainty.'],
#    'intuition': 'Every AI model ultimately relies on mathematical principles.',
#    'key_concepts': ['Linear Algebra', 'Probability', 'Calculus'],
#    'prerequisites': ['Basic Algebra'],
#    'key_takeaways': ['Mathematics is the foundation of AI.']},
#   'history': {'problem_before': '',
#    'historical_motivation': '',
#    'impact_on_ai': ''},
#   'timeline': [],
#   'researchers': [],
#   'papers': [],
#   'applications': [],
#   'future': {'open_problems': [], 'future_directions': []},
#   'faq': [],
#   'relationships': {'parent_topics': [],
#    'child_topics': [],
#    'related_topics': []}},
#  'parents': [],
#  'children': [],
#  'researchers': [],
#  'papers': []}

# %%
assistant.context_statistics(
    "Mathematics"
)
# Out:
# {'parents': 0, 'children': 0, 'researchers': 0, 'papers': 0}
